# %%
#Lee archivos CSV, los cuales están separados por comas
#Tienes que poner exactamente el nombre del archivo
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
d = pd.read_csv("/content/drive/MyDrive/POO/ETF prices.csv")
d

# %%
#Shape da la dimensión de la matriz
d.shape

# %%
#Ndim da la dimensión como objeto de python
d.ndim

# %%
#Con Drop podemos quitar columnas
d.drop(columns = ['high', 'low'])

# %%
#Iloc corta la base de datos por índices (renglones)
d.iloc[0:100]

# %%
#Seleccionas las columnas en la posición 1,2,5 (la primera columna es 0)
d.iloc[:, [1, 2, 5]]

# %%
#Te dice cuantos elementos únicos hay
d['close'].value_counts()

# %%
#Información estadística descriptiva de tu base de datos
d.describe()

# %%
#Corte y nombre la base de datos diferente
e = d.drop(columns = ["high", "low"])
e

# %%
#Eje 0 o axis 0: renglones
#Eje 1 o axis 1: columnas

e = d.drop(columns = ["fund_symbol"])
e

# %%
#Para sacar el promedio del eje 1
e.mean(axis = 1)

# %%
#Para sacar el promedio del eje 0
e.mean(axis = 0)
