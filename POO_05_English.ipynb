# %% [markdown]
# #Clases, herencias y polimorfismos

# %% [markdown]
# ###Definiciones.

# %%
#Vamos a crear una definición en (que es una función integrada en python)
def Milanesi(a,b,c):
  x = a+b*c
  return x

# %%
Milanesi (1,2,3)
# Out:
# 7

# %%
#Vamos a crear una definición que calcule la inversa de una matriz
import numpy as np
def Inv_Matrix(M):
  x = np.linalg.inv(M)
  return x

# %%
b = np.array([[1,2,3], [0,1,0],[2,1,1]])
b
# Out:
# array([[1, 2, 3],
#        [0, 1, 0],
#        [2, 1, 1]])

# %%
Inv_Matrix (b)
# Out:
# array([[-0.2, -0.2,  0.6],
#        [ 0. ,  1. ,  0. ],
#        [ 0.4, -0.6, -0.2]])

# %%
#Matriz con data random, para que te lo deje fijos pones el seed (12)
np.random.seed (12)
y=np.random.randint(1,20,size=(2,2))
Inv_Matrix(y)
# Out:
# array([[-0.03333333,  0.07777778],
#        [ 0.2       , -0.13333333]])

# %%
y
# Out:
# array([[12,  7],
#        [18,  3]])

# %%
#Te dice la dimensión de la matriz
b.shape
# Out:
# (3, 3)
